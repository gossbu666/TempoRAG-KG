# %% [markdown]
# # 02 — Knowledge graph overview (T8)
#
# **Status:** stub. Fill in when T8 lands `results/kg/graph.pkl` and `results/kg/build_stats.json`.
#
# **Checkpoint 2 gate.** Non-null validity coverage rate must be ≥ 30% — if not, the temporal filter is mostly a no-op and we flag this as a study limitation.

# %%
import json
import os
import sys
from pathlib import Path


def find_root(start: Path) -> Path:
    p = start.resolve()
    for cand in [p, *p.parents]:
        if (cand / ".git").exists():
            return cand
    raise RuntimeError(f"project root not found from {start}")


ROOT = find_root(Path.cwd())
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import pandas as pd

print(f"Project root: {ROOT}")

# %% [markdown]
# ## TODO — fill during T8
#
# Cells to add:
#
# 1. Load `results/kg/graph.pkl` (NetworkX `MultiDiGraph`).
# 2. Display `n_nodes`, `n_edges`, `avg_degree`, `non_null_validity_rate`.
# 3. Plot degree distribution (histogram).
# 4. Sample 10 random edges; show `subject / predicate / object / valid_from / valid_to / source_chunk_id`.
# 5. Load `results/kg/build_stats.json`; show total cost, wall-clock, triples extracted.
