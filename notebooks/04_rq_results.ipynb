# %% [markdown]
# # 04 — Final RQ results for the Progress Report (T13 + T14 + T16)
#
# **Status:** stub. Fill in as T13 / T14 / T16 land their `results/runs/rq*_*.json` files.
#
# Tables generated here are intended to paste directly into `proposal/progress_report.tex` (T17).

# %%
import json
import os
import sys
from pathlib import Path


def find_root(start: Path) -> Path:
    p = start.resolve()
    for cand in [p, *p.parents]:
        if (cand / ".git").exists():
            return cand
    raise RuntimeError(f"project root not found from {start}")


ROOT = find_root(Path.cwd())
os.chdir(ROOT)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import pandas as pd

print(f"Project root: {ROOT}")

# %% [markdown]
# ## TODO — fill during T13 + T14 + T16
#
# Cells to add:
#
# 1. **RQ3 extraction** (T13): precision / recall / F1 per pattern type (explicit year / Type 3b relative / conflicting), with ±1 yr tolerance.
# 2. **RQ1 failure modes** (T14): distribution across the 5-type taxonomy (Stale / Conflicting / Missing / Type 3b / Hop) with one example question per type.
# 3. **RQ4 generator ablation** (T16): ΔF1 = Full − KG²RAG per generator (LLaMA-8B / LLaMA-70B / Gemini Flash / GPT-4o-mini); test inverse-scaling hypothesis.
# 4. Combined report-ready table for Progress Report §6 (Updated Methodology + Results).
